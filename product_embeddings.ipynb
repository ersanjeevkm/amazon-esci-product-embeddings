# %% [markdown]
# <a href="https://colab.research.google.com/github/ersanjeevkm/amazon-esci-product-embeddings/blob/main/product_embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Download and load amazon esci product catalogue dataset

# %%
# !wget https://github.com/amazon-science/esci-data/raw/refs/heads/main/shopping_queries_dataset/shopping_queries_dataset_products.parquet
# Out:
# --2025-06-19 16:49:09--  https://github.com/amazon-science/esci-data/raw/refs/heads/main/shopping_queries_dataset/shopping_queries_dataset_products.parquet
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/amazon-science/esci-data/refs/heads/main/shopping_queries_dataset/shopping_queries_dataset_products.parquet [following]
# --2025-06-19 16:49:09--  https://media.githubusercontent.com/media/amazon-science/esci-data/refs/heads/main/shopping_queries_dataset/shopping_queries_dataset_products.parquet
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1108857465 (1.0G) [application/octet-stream]
# Saving to: ‘shopping_queries_dataset_products.parquet’
#
# shopping_queries_da 100%[===================>]   1.03G   253MB/s    in 4.0s
#
# 2025-06-19 16:49:13 (267 MB/s) - ‘shopping_queries_dataset_products.parquet’ saved [1108857465/1108857465]

# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
df_products = pd.read_parquet('shopping_queries_dataset_products.parquet')

# %%
df_products.columns.tolist()
# Out:
# ['product_id',
#  'product_title',
#  'product_description',
#  'product_bullet_point',
#  'product_brand',
#  'product_color',
#  'product_locale']

# %%
df_products.head()
# Out:
#    product_id                                      product_title  \
# 0  B079VKKJN7  11 Degrees de los Hombres Playera con Logo, Ne...
# 1  B079Y9VRKS          Camiseta Eleven Degrees Core TS White (M)
# 2  B07DP4LM9H  11 Degrees de los Hombres Core Pull Over Hoodi...
# 3  B07G37B9HP          11 Degrees Poli Panel Track Pant XL Black
# 4  B07LCTGDHY  11 Degrees Gorra Trucker Negro OSFA (Talla úni...
#
#                                  product_description  \
# 0  Esta playera con el logo de la marca Carrier d...
# 1                                               None
# 2  La sudadera con capucha Core Pull Over de 11 G...
# 3                                               None
# 4                                               None
#
#                                 product_bullet_point product_brand  \
# 0  11 Degrees Negro Playera con logo\nA estrenar ...    11 Degrees
# 1                                               None    11 Degrees
# 2  11 Degrees Azul Core Pull Over Hoodie\nA estre...    11 Degrees
# 3                                               None    11 Degrees
# 4                                               None    11 Degrees
#
#   product_color product_locale
# 0         Negro             es
# 1        Blanco             es
# 2          Azul             es
# 3          None             es
# 4       Negro (             es

# %%
df_products['product_locale'].unique()
# Out:
# array(['es', 'us', 'jp'], dtype=object)

# %%
df_products = df_products[df_products['product_locale'] == 'us']

# %%
df_products.head()
# Out:
#         product_id                                      product_title  \
# 167168  B003O0MNGC  Delta BreezSignature VFB25ACH 80 CFM Exhaust B...
# 167169  B00MARNO5Y  Aero Pure AP80RVLW Super Quiet 80 CFM Recessed...
# 167170  B011RX6PNO  Aero Pure AP120H-SL W Slim Fit 120 CFM Bathroo...
# 167171  B01MZIK0PI  Delta Electronics (Americas) Ltd. RAD80 Delta ...
# 167172  B01N5Y6002  Delta Electronics (Americas) Ltd. GBR80HLED De...
#
#        product_description                               product_bullet_point  \
# 167168                None  Virtually silent at less than 0.3 sones\nPreci...
# 167169                None  Super quiet 80CFM energy efficient fan virtual...
# 167170                None  Slim Fit Housing Fits Into 2" X 6" Ceiling Joi...
# 167171                None  Quiet operation at 1.5 Sones\nPrecision engine...
# 167172                None  Ultra energy-efficient LED module (11-watt equ...
#
#                             product_brand  \
# 167168  DELTA ELECTRONICS (AMERICAS) LTD.
# 167169                          Aero Pure
# 167170                          Aero Pure
# 167171  DELTA ELECTRONICS (AMERICAS) LTD.
# 167172  DELTA ELECTRONICS (AMERICAS) LTD.
#
#                                        product_color product_locale
# 167168                                         White             us
# 167169                                         White             us
# 167170                                  White Finish             us
# 167171                                   With Heater             us
# 167172  With LED Light, Dual Speed & Humidity Sensor             us

# %%
if df_products['product_id'].nunique() == len(df_products):
    print("All product IDs are unique.")
else:
    print("Product IDs are not unique.")
# Out:
# All product IDs are unique.

# %%
df_products_context = pd.DataFrame()
df_products_context['product_id'] = df_products['product_id']
df_products_context['product_info'] = (
    "Product Title:" + df_products['product_title'].astype(str) +
    "\nProduct Description:" + df_products['product_description'].astype(str) +
    "\nProduct Bullet Points:" + df_products['product_bullet_point'].astype(str) +
    "\nProduct Brand:" + df_products['product_brand'].astype(str) +
    "\nProduct Color:" + df_products['product_color'].astype(str)
)

# %%
df_products_context.head()
# Out:
#         product_id                                       product_info
# 167168  B003O0MNGC  Product Title:Delta BreezSignature VFB25ACH 80...
# 167169  B00MARNO5Y  Product Title:Aero Pure AP80RVLW Super Quiet 8...
# 167170  B011RX6PNO  Product Title:Aero Pure AP120H-SL W Slim Fit 1...
# 167171  B01MZIK0PI  Product Title:Delta Electronics (Americas) Ltd...
# 167172  B01N5Y6002  Product Title:Delta Electronics (Americas) Ltd...

# %%
df_products_context.iloc[0]['product_info']
# Out:
# 'Product Title:Delta BreezSignature VFB25ACH 80 CFM Exhaust Bath Fan with Humidity Sensor\nProduct Description:None\nProduct Bullet Points:Virtually silent at less than 0.3 sones\nPrecision engineered with DC brushless motor for extended reliability\nEasily switch in and out of humidity sensing mode by toggling wall switch\nENERGY STAR qualified for efficient cost-saving operation\nPrecision engineered with DC brushless motor for extended reliability, this fan will outlast many household appliances\nProduct Brand:DELTA ELECTRONICS (AMERICAS) LTD.\nProduct Color:White'
